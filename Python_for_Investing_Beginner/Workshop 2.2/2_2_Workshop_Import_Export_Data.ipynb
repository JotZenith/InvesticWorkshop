# %% [markdown]
# # Import

# %% [markdown]
# Link สำหรับดาวน์โหลดไฟล์ : https://drive.google.com/drive/folders/1G55bp9-aFwpIRKrKjd3g-Vkz4ebQ5Emt?usp=sharing

# %% [markdown]
# # Import CSV/EXCEL

# %% [markdown]
# ## Import CSV

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-91cad9a7-1461-406d-ae67-1c3581d8a3fd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-91cad9a7-1461-406d-ae67-1c3581d8a3fd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data_csv = pd.read_csv('tesla.csv')
data_csv
# Out:
#            Date         Open         High          Low        Close  \
# 0    2021-01-04   719.460022   744.489990   717.190002   729.770020
# 1    2021-01-05   723.659973   740.840027   719.200012   735.109985
# 2    2021-01-06   758.489990   774.000000   749.099976   755.979980
# 3    2021-01-07   777.630005   816.989990   775.200012   816.039978
# 4    2021-01-08   856.000000   884.489990   838.390015   880.020020
# ..          ...          ...          ...          ...          ...
# 247  2021-12-27  1073.670044  1117.000000  1070.719971  1093.939941
# 248  2021-12-28  1109.489990  1119.000000  1078.420044  1088.469971
# 249  2021-12-29  1098.640015  1104.000000  1064.140015  1086.189941
# 250  2021-12-30  1061.329956  1095.550049  1053.150024  1070.339966
# 251  2021-12-31  1073.439941  1082.000000  1054.589966  1056.780029
#
#        Adj Close    Volume
# 0     729.770020  48638200
# 1     735.109985  32245200
# 2     755.979980  44700000
# 3     816.039978  51498900
# ...

# %% [markdown]
# ## Import Excel

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6ee80be2-6596-4a7a-8122-3820bd80ebda" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ee80be2-6596-4a7a-8122-3820bd80ebda">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data_excel = pd.read_excel('tesla.xlsx')
data_excel
# Out:
#           Date         Open         High          Low        Close  \
# 0   2021-01-04   719.460022   744.489990   717.190002   729.770020
# 1   2021-01-05   723.659973   740.840027   719.200012   735.109985
# 2   2021-01-06   758.489990   774.000000   749.099976   755.979980
# 3   2021-01-07   777.630005   816.989990   775.200012   816.039978
# 4   2021-01-08   856.000000   884.489990   838.390015   880.020020
# ..         ...          ...          ...          ...          ...
# 247 2021-12-27  1073.670044  1117.000000  1070.719971  1093.939941
# 248 2021-12-28  1109.489990  1119.000000  1078.420044  1088.469971
# 249 2021-12-29  1098.640015  1104.000000  1064.140015  1086.189941
# 250 2021-12-30  1061.329956  1095.550049  1053.150024  1070.339966
# 251 2021-12-31  1073.439941  1082.000000  1054.589966  1056.780029
#
#        Adj Close    Volume
# 0     729.770020  48638200
# 1     735.109985  32245200
# 2     755.979980  44700000
# 3     816.039978  51498900
# ...

# %% [markdown]
# # Import yahoo finance

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 1.3 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
import yfinance as yf

# %%
beg = '2021-01-01'
ending = '2022-11-30'

# %%
data = yf.download('TSLA', start=beg, end=ending)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  239.820007  248.163330  239.063339  243.256668  243.256668
# 2021-01-05  241.220001  246.946671  239.733337  245.036667  245.036667
# 2021-01-06  252.830002  258.000000  249.699997  251.993332  251.993332
# 2021-01-07  259.209991  272.329987  258.399994  272.013336  272.013336
# 2021-01-08  285.333344  294.829987  279.463318  293.339996  293.339996
# ...                ...         ...         ...         ...         ...
# 2022-11-22  168.630005  170.919998  166.190002  169.910004  169.910004
# 2022-11-23  173.570007  183.619995  172.500000  183.199997  183.199997
# 2022-11-25  185.059998  185.199997  180.630005  182.860001  182.860001
# 2022-11-28  179.960007  188.500000  179.000000  182.919998  182.919998
# 2022-11-29  184.990005  186.380005  178.750000  180.830002  180.830002
#
#                Volume
# Date
# 2021-01-04  145914600
# 2021-01-05   96735600
# 2021-01-06  134100000
# ...

# %% [markdown]
# # Export

# %% [markdown]
# ## To CSV

# %%
data.to_csv('Teslaexport.csv')

# %%
from google.colab import files
files.download("Teslaexport.csv")

# %% [markdown]
# ## To EXCEL

# %%
data.to_excel('teslaexcel.xlsx')

# %%
from google.colab import files
files.download("teslaexcel.xlsx")
